# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install seaborn
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install nbformat --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/LuciaMaRu/Proyecto-1/refs/heads/main/MCD.csv')
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1966-07-05    0.000000    0.273663    0.267490    0.269547    0.115991
# 1      1966-07-06    0.000000    0.283951    0.267490    0.283951    0.122190
# 2      1966-07-07    0.000000    0.291152    0.271605    0.273663    0.117762
# 3      1966-07-08    0.000000    0.276749    0.267490    0.276749    0.119090
# 4      1966-07-11    0.000000    0.283951    0.272634    0.275720    0.118648
# ...           ...         ...         ...         ...         ...         ...
# 14647  2024-09-13  294.489990  296.739990  292.619995  296.529999  296.529999
# 14648  2024-09-16  297.420013  300.109985  295.040009  296.690002  296.690002
# 14649  2024-09-17  297.000000  297.390015  292.170013  293.750000  293.750000
# 14650  2024-09-18  293.880005  295.100006  290.369995  292.029999  292.029999
# 14651  2024-09-19  294.250000  295.079987  290.899994  293.850006  293.850006
#
#         Volume
# 0       388800
# ...

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  14652.000000  14652.000000  14652.000000  14652.000000  14652.000000
# mean      50.710007     51.143266     50.329801     50.746652     41.162607
# std       73.844970     74.349949     73.292929     73.833827     69.263743
# min        0.000000      0.156379      0.152263      0.154321      0.066407
# 25%        1.586420      1.607253      1.567901      1.589506      0.702369
# 50%       17.219999     17.474999     17.056250     17.265000      9.334254
# 75%       64.832502     65.440001     64.615000     64.980001     43.152880
# max      300.950012    302.390015    299.309998    300.529999    296.690002
#
#              Volume
# count  1.465200e+04
# mean   4.270940e+06
# std    3.102599e+06
# min    4.860000e+04
# 25%    2.357100e+06
# 50%    3.588300e+06
# 75%    5.393350e+06
# max    8.698130e+07

# %%
df['Date'] = pd.to_datetime(df.Date)
df.head()
# Out:
#         Date  Open      High       Low     Close  Adj Close   Volume
# 0 1966-07-05   0.0  0.273663  0.267490  0.269547   0.115991   388800
# 1 1966-07-06   0.0  0.283951  0.267490  0.283951   0.122190   692550
# 2 1966-07-07   0.0  0.291152  0.271605  0.273663   0.117762  1858950
# 3 1966-07-08   0.0  0.276749  0.267490  0.276749   0.119090  1239300
# 4 1966-07-11   0.0  0.283951  0.272634  0.275720   0.118648   656100

# %%
df[(df['Volume'] == 48600)]
# Out:
#           Date  Open      High       Low     Close  Adj Close  Volume
# 24  1966-08-08   0.0  0.241770  0.239712  0.241770   0.104038   48600
# 434 1968-03-26   0.0  0.631687  0.627572  0.631687   0.271827   48600

# %%
df[(df['Volume'] == 86981300)]
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 10133 2006-10-05  39.959999  40.049999  39.669998  39.799999  23.639261
#
#          Volume
# 10133  86981300

# %%
df3=df[(df['Date'] >= '2024-01-01') & (df['Date'] <= '2024-12-30')]
df3
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 14471 2024-01-02  295.049988  297.279999  295.049988  297.040009  291.756592
# 14472 2024-01-03  297.000000  297.989990  294.250000  294.390015  289.153717
# 14473 2024-01-04  295.320007  297.269989  290.920013  291.739990  286.550812
# 14474 2024-01-05  289.209991  290.329987  287.200012  288.989990  283.849701
# 14475 2024-01-08  288.510010  292.000000  287.519989  291.899994  286.707947
# ...          ...         ...         ...         ...         ...         ...
# 14647 2024-09-13  294.489990  296.739990  292.619995  296.529999  296.529999
# 14648 2024-09-16  297.420013  300.109985  295.040009  296.690002  296.690002
# 14649 2024-09-17  297.000000  297.390015  292.170013  293.750000  293.750000
# 14650 2024-09-18  293.880005  295.100006  290.369995  292.029999  292.029999
# 14651 2024-09-19  294.250000  295.079987  290.899994  293.850006  293.850006
#
#         Volume
# 14471  4458400
# ...

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  14652.000000  14652.000000  14652.000000  14652.000000  14652.000000
# mean      50.710007     51.143266     50.329801     50.746652     41.162607
# std       73.844970     74.349949     73.292929     73.833827     69.263743
# min        0.000000      0.156379      0.152263      0.154321      0.066407
# 25%        1.586420      1.607253      1.567901      1.589506      0.702369
# 50%       17.219999     17.474999     17.056250     17.265000      9.334254
# 75%       64.832502     65.440001     64.615000     64.980001     43.152880
# max      300.950012    302.390015    299.309998    300.529999    296.690002
#
#              Volume
# count  1.465200e+04
# mean   4.270940e+06
# std    3.102599e+06
# min    4.860000e+04
# 25%    2.357100e+06
# 50%    3.588300e+06
# 75%    5.393350e+06
# max    8.698130e+07

# %%
colu = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
plt.figure(figsize=(16,12))
for i, col in enumerate(colu, 1):
    plt.subplot(4, 3, i)  
    sns.boxplot(data=df, x=col, palette='Set2')
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\marul\AppData\Local\Temp\ipykernel_31452\2366961160.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\marul\AppData\Local\Temp\ipykernel_31452\2366961160.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\marul\AppData\Local\Temp\ipykernel_31452\2366961160.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\marul\AppData\Local\Temp\ipykernel_31452\2366961160.py:5: FutureWarning:
#
#
#
# ...

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 20)) 
fig.tight_layout(pad=5.0) 

# Subplot 1: Date
sns.boxplot(data=df, x='Date', color='teal', ax=axs[0, 0])
axs[0, 0].set_title('Distribución de Date')

# Subplot 2: Open
sns.histplot(data=df, x='Open', kde=True, bins=30, color='lightblue', ax=axs[0, 1])
axs[0, 1].set_title('Distribución de Open')

# Subplot 3: High
sns.histplot(data=df, x='High', kde=True, bins=30, color='skyblue', ax=axs[0, 2])
axs[0, 2].set_title('Distribución de High')

# Subplot 4: Low
sns.histplot(data=df, x='Low', kde=True, bins=30, color='lightgreen', ax=axs[0, 3])
axs[0, 3].set_title('Distribución de Low')

# Subplot 5: Close
sns.histplot(data=df, x='Close', kde=True, bins=30, color='orange', ax=axs[1, 0])
axs[1, 0].set_title('Distribución de Close')

# Subplot 6: Adj Close
sns.histplot(data=df, x='Adj Close', kde=True, bins=30, color='blue', ax=axs[1, 1])
axs[1, 1].set_title('Distribución de Adj Close')


# Subplot 7: #Volume
sns.boxplot(data=df, x='Volume', color='lightcoral', ax=axs[1, 2])
axs[1, 2].set_title('Distribución de Volume')

# Ocultar el subplot vacío (espacio en la cuadrícula)
axs[1, 3].axis('off')

# Mostrar los gráficos
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10,10))
# Gráfico de calor
sns.heatmap(correlation_matrix, annot=True, cmap='inferno')
# Mostrar gráfico
plt.show()

# %%
#libreria para gráficos avanzados
import plotly.graph_objects as go

df = pd.DataFrame(df)

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                                       open=df['Open'],
                                       high=df['High'],
                                       low=df['Low'],
                                       close=df['Close'])])


fig.update_layout(title='Gráfico de Velas', xaxis_title='Fecha', yaxis_title='Precio')
fig.show()

# %%
#MACHINE LEARNING

# %%
import numpy as np

# %%
pip install --pre scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#ANUAL

# %%
# Dividir los datos en conjunto de entrenamiento y prueba
X = df[['Date']].values
y = df['Adj Close'].values     # Variable dependiente
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Crear el modelo de características polinómicas de grado 2
poly = PolynomialFeatures(degree=6)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
# Crear el modelo de regresión lineal
model = LinearRegression()
model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Predecir con el conjunto de prueba
y_pred = model.predict(X_test_poly)

# Evaluación del modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error (MSE): 57.64124424046876
# R^2 Score: 0.987801203238435

# %%
# Gráfica de los datos originales y el modelo ajustado
plt.scatter(X, y, s=1, color='skyblue', label='Datos originales')

# Ordenar X_test para la visualización
sorted_indices = np.argsort(X_test.flatten())  # Obtener índices de ordenamiento
X_test_sorted = X_test[sorted_indices]
y_pred_sorted = y_pred[sorted_indices]

plt.plot(X_test_sorted, y_pred_sorted, color='red', label='Modelo polinómico')
plt.title('Regresión Polinómica')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.legend()
plt.show()

# %%
#Diaria 2024

# %%
# Dividir los datos en conjunto de entrenamiento y prueba
X = df3[['Date']].values  # Variable independiente
y = df3['Adj Close'].values     # Variable dependiente
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Crear el modelo de características polinómicas de grado 2
poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
# Crear el modelo de regresión lineal
model = LinearRegression()
model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Predecir con el conjunto de prueba
y_pred = model.predict(X_test_poly)

# Evaluación del modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error (MSE): 186.69632218151912
# R^2 Score: 0.12135757330782526

# %%
# Gráfica de los datos originales y el modelo ajustado
plt.scatter(X, y, s=5, color='skyblue', label='Datos originales')

# Ordenar X_test para la visualización
sorted_indices = np.argsort(X_test.flatten())  # Obtener índices de ordenamiento
X_test_sorted1 = X_test[sorted_indices]
y_pred_sorted1 = y_pred[sorted_indices]

plt.plot(X_test_sorted, y_pred_sorted, color='red', label='Modelo polinómico')
plt.title('Regresión Polinómica')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.legend()
plt.show()
